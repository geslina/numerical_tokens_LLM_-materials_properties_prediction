# %% [markdown]
# #### Author: Alexis Geslin

# %%
import re
import time
import glob
import pandas as pd
import numpy as np
import argparse
from statistics import stdev
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/MyDrive/cours/cs224n/project/LLM-Prop/
# Out:
# /content/drive/MyDrive/cours/cs224n/project/LLM-Prop

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
    print('-'*20)
    print(f'I have {torch.cuda.device_count()} devices, currently on {torch.cuda.current_device()}')
    print('-'*20)
else:
    print('-'*20)
    print("You are running on CPU only")
    print('-'*20)
    device = torch.device("cpu")
# Out:
# --------------------
# I have 1 devices, currently on 0
# --------------------

# %%
train_labels_data = pd.read_csv(f'./embeddings/pred_labels_train_train15000_200epoch_125098.csv')
valid_labels_data = pd.read_csv(f'./embeddings/pred_labels_valid_train15000_200epoch_9945.csv')
test_labels_data = pd.read_csv(f'./embeddings/pred_labels_test_train15000_200epoch_11531.csv')

train_embeddings  = pd.read_csv(f'./embeddings/embeddings_train_train15000_200epoch_125098.csv', header=None)
valid_embeddings  = pd.read_csv(f'./embeddings/embeddings_valid_train15000_200epoch_9945.csv', header=None)
test_embeddings  = pd.read_csv(f'./embeddings/embeddings_test_train15000_200epoch_11531.csv', header=None)

train_numerical_tokens = pd.read_csv(f'./embeddings/train_numerical_tokens_5_3_1.csv', header=0)
valid_numerical_tokens = pd.read_csv(f'./embeddings/valid_numerical_tokens_5_3_1.csv', header=0)
test_numerical_tokens = pd.read_csv(f'./embeddings/test_numerical_tokens_5_3_1.csv', header=0)

# %%
#printing shapes
print(train_labels_data.shape, valid_labels_data.shape, test_labels_data.shape)
print(train_embeddings.shape, valid_embeddings.shape, test_embeddings.shape)
print(train_numerical_tokens.shape, valid_numerical_tokens.shape, test_numerical_tokens.shape)
# Out:
# (125098, 2) (9945, 2) (11531, 2)
# (125098, 512) (9945, 512) (11531, 512)
# (125098, 9) (9945, 9) (11531, 9)

# %%
#concat embeddings and numerical tokens and make it a tensor
X_train = torch.tensor(np.concatenate((train_embeddings, train_numerical_tokens), axis=1),device=device).float()
X_valid = torch.tensor(np.concatenate((valid_embeddings, valid_numerical_tokens), axis=1),device=device).float()
X_test = torch.tensor(np.concatenate((test_embeddings, test_numerical_tokens), axis=1),device=device).float()

Y_train = torch.tensor(train_labels_data.label.values,device=device).float().reshape(-1,1)
Y_valid = torch.tensor(valid_labels_data.label.values,device=device).float().reshape(-1,1)
Y_test = torch.tensor(test_labels_data.label.values,device=device).float().reshape(-1,1)

#print shapes
print(X_train.shape, Y_train.shape)
print(X_valid.shape, Y_valid.shape)
print(X_test.shape, Y_test.shape)
# Out:
# torch.Size([125098, 521]) torch.Size([125098, 1])
# torch.Size([9945, 521]) torch.Size([9945, 1])
# torch.Size([11531, 521]) torch.Size([11531, 1])

# %%
dim_embeddings = train_embeddings.shape[1]
dim_numerical = train_numerical_tokens.shape[1]
mae_loss_function = nn.L1Loss()

# %%
X_train_mini = X_train[:10000]
Y_train_mini = Y_train[:10000]

bs = 256 if torch.cuda.is_available() else 32
print(bs)

train_dataset = torch.utils.data.TensorDataset(X_train, Y_train)
train_dataset_mini = torch.utils.data.TensorDataset(X_train_mini, Y_train_mini)
valid_dataset = torch.utils.data.TensorDataset(X_valid, Y_valid)
test_dataset = torch.utils.data.TensorDataset(X_test, Y_test)

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=bs, shuffle=False)
train_dataloader_mini = torch.utils.data.DataLoader(train_dataset_mini, batch_size=bs, shuffle=False)
valid_dataloader = torch.utils.data.DataLoader(valid_dataset, batch_size=bs, shuffle=False)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=bs, shuffle=False)
# Out:
# 256

# %%
class myDualmodel(nn.Module):
    def __init__(self, embeddings_dim,num_dim,drop_rate=0.3):
        super(myDualmodel, self).__init__()
        self.num_dim = num_dim
        self.embeddings_dim = embeddings_dim

        self.MLP_embedding = nn.Sequential(
            nn.Dropout(drop_rate),
            nn.Linear(embeddings_dim, 32),
            nn.ReLU()
        )

        self.MLP_numerical = nn.Sequential(
            nn.Linear(num_dim, 32),
            nn.Dropout(drop_rate),
            nn.ReLU()
        )

        self.MLP_head = nn.Sequential(
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(drop_rate),
            nn.Linear(32, 1)
        )

    def forward(self, x1, x2):
        x1_out = self.MLP_embedding(x1)
        x2_out = self.MLP_numerical(x2)
        x_out = torch.cat((x1_out, x2_out), dim=1)
        x_out = self.MLP_head(x_out)
        return x_out

# %%
def init_weights(m):
    if isinstance(m, torch.nn.Linear):
        torch.nn.init.kaiming_uniform_(m.weight, nonlinearity='relu')
        if m.bias is not None:
            torch.nn.init.zeros_(m.bias)

class ResidualBlock(nn.Module):
    def __init__(self, in_features):
        super().__init__()
        self.fc = nn.Linear(in_features, in_features)
        self.bn = nn.BatchNorm1d(in_features)

    def forward(self, x):
        return nn.functional.relu(self.bn(self.fc(x)) + x)

class ResidualBlock2(nn.Module):
    def __init__(self, in_features):
        super().__init__()
        self.fc = nn.Linear(in_features, in_features)
        self.bn = nn.BatchNorm1d(in_features)

    def forward(self, x):
        return self.bn(self.fc(x)) + x

class myDualmodel2(nn.Module):
    def __init__(self, embeddings_dim,num_dim,drop_rate=0.3):
        super(myDualmodel2, self).__init__()
        self.num_dim = num_dim
        self.embeddings_dim = embeddings_dim

        self.MLP_embedding = nn.Sequential(
            nn.BatchNorm1d(num_features=embeddings_dim),
            nn.Linear(embeddings_dim, 32),
            nn.ReLU(),
            nn.Dropout(drop_rate),
        )

        self.MLP_numerical = nn.Sequential(
            nn.BatchNorm1d(num_features=num_dim),
            nn.Linear(num_dim, 32),
            nn.ReLU()
        )

        self.MLP_head = nn.Sequential(
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(drop_rate),
            nn.Linear(32, 1)
        )

    def forward(self, x1, x2):
        x1_out = self.MLP_embedding(x1)
        x2_out = self.MLP_numerical(x2)
        x_out = torch.cat((x1_out, x2_out), dim=1)
        x_out = self.MLP_head(x_out)
        return x_out

class myDualmodel3(nn.Module):
    def __init__(self, embeddings_dim,num_dim,drop_rate=0.3):
        super(myDualmodel3, self).__init__()
        self.num_dim = num_dim
        self.embeddings_dim = embeddings_dim

        self.MLP_embedding = nn.Sequential(
            nn.Dropout(drop_rate),
            ResidualBlock(embeddings_dim),
            nn.LeakyReLU(),
            nn.Linear(embeddings_dim, 32),
            nn.LeakyReLU()
        )

        self.MLP_numerical = nn.Sequential(
            nn.Dropout(drop_rate),
            ResidualBlock(num_dim),
            nn.LeakyReLU(),
            nn.Linear(num_dim, 32),
            nn.Dropout(drop_rate),
            nn.ReLU()
        )

        self.MLP_head = nn.Sequential(
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(drop_rate),
            nn.Linear(32, 1)
        )

        for m in self.MLP_embedding:
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight)
                print(f'initialized {m}')
        for m in self.MLP_numerical:
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight)
                print(f'initialized {m}')

        for m in self.MLP_head:
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight)
                print(f'initialized {m}')


    def forward(self, x1, x2):
        x1_out = self.MLP_embedding(x1)
        x2_out = self.MLP_numerical(x2)
        x_out = torch.cat((x1_out, x2_out), dim=1)
        x_out = self.MLP_head(x_out)
        return x_out



class myDualmodel4(nn.Module):
    def __init__(self, embeddings_dim,num_dim,drop_rate=0.3):
        super(myDualmodel4, self).__init__()
        self.num_dim = num_dim
        self.embeddings_dim = embeddings_dim

        self.MLP_embedding = nn.Sequential(
            nn.Dropout(drop_rate),
            ResidualBlock(embeddings_dim),
            nn.LeakyReLU(),
            ResidualBlock(embeddings_dim),
            nn.LeakyReLU(),
            nn.Linear(embeddings_dim, 128),
            nn.LeakyReLU(),
            nn.Linear(128, 32),
            nn.LeakyReLU()
        )

        self.MLP_numerical = nn.Sequential(
            nn.Dropout(drop_rate),
            ResidualBlock(num_dim),
            nn.LeakyReLU(),
            nn.Linear(num_dim, 64),
            nn.LeakyReLU(),
            ResidualBlock(64),
            nn.LeakyReLU(),
            nn.Linear(64, 32),
            nn.Dropout(drop_rate),
            nn.ReLU()
        )

        self.MLP_head = nn.Sequential(
            ResidualBlock(64),
            nn.LeakyReLU(),
            nn.Linear(64, 32),
            nn.LeakyReLU(),
            nn.Dropout(drop_rate),
            nn.Linear(32, 1)
        )

        for m in self.MLP_embedding:
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight)
                print(f'initialized {m}')
        for m in self.MLP_numerical:
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight)
                print(f'initialized {m}')

        for m in self.MLP_head:
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight)
                print(f'initialized {m}')


    def forward(self, x1, x2):
        x1_out = self.MLP_embedding(x1)
        x2_out = self.MLP_numerical(x2)
        x_out = torch.cat((x1_out, x2_out), dim=1)
        x_out = self.MLP_head(x_out)
        return x_out

class myDualmodel5(nn.Module):
    def __init__(self, embeddings_dim,num_dim,drop_rate=0.3):
        super(myDualmodel5, self).__init__()
        self.num_dim = num_dim
        self.embeddings_dim = embeddings_dim

        self.MLP_embedding = nn.Sequential(
            nn.Dropout(drop_rate),
            ResidualBlock2(embeddings_dim),
            nn.LeakyReLU(),
            nn.Linear(embeddings_dim, 32),
            nn.LeakyReLU()
        )

        self.MLP_numerical = nn.Sequential(
            nn.Dropout(drop_rate),
            ResidualBlock2(num_dim),
            nn.LeakyReLU(),
            nn.Linear(num_dim, 32),
            nn.LeakyReLU(),
            nn.Dropout(drop_rate)
        )

        self.MLP_head = nn.Sequential(
            nn.Linear(64, 32),
            nn.LeakyReLU(),
            nn.Dropout(drop_rate),
            nn.Linear(32, 1)
        )

        for m in self.MLP_embedding:
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight)
                print(f'initialized {m}')
        for m in self.MLP_numerical:
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight)
                print(f'initialized {m}')

        for m in self.MLP_head:
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight)
                print(f'initialized {m}')


    def forward(self, x1, x2):
        x1_out = self.MLP_embedding(x1)
        x2_out = self.MLP_numerical(x2)
        x_out = torch.cat((x1_out, x2_out), dim=1)
        x_out = self.MLP_head(x_out)
        return x_out

# %%
# train_results = pd.DataFrame(index = np.arange(30))
# valid_results = pd.DataFrame(index = np.arange(30))

# %%
model = myDualmodel5(dim_embeddings,dim_numerical,drop_rate=0.1)
model.to(device)
best_valid_loss = 5


optimizer = optim.Adam(model.parameters(), lr=0.0015)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, verbose=True)
epochs = 100
my_training_loader = train_dataloader
# Out:
# initialized Linear(in_features=512, out_features=32, bias=True)
# initialized Linear(in_features=9, out_features=32, bias=True)
# initialized Linear(in_features=64, out_features=32, bias=True)
# initialized Linear(in_features=32, out_features=1, bias=True)

# %%
# optimizer = optim.Adam(model.parameters(), lr=0.00015,weight_decay=0.01)


train_recording = []
valid_recording =[]


for epoch in range(epochs):
    model.train()
    train_loss = 0
    for i, (x, y) in enumerate(my_training_loader):
        optimizer.zero_grad()
        y_pred = model(x[:,:dim_embeddings], x[:,dim_embeddings:])
        loss = mae_loss_function(y_pred, y)
        train_loss += loss.item()
        loss.backward()
        optimizer.step()
        # if i % 10000 == 0:
    train_loss /= len(my_training_loader)
    train_recording.append(train_loss)
    print(f'Epoch {epoch}, Training Loss {train_loss}')

    model.eval()
    valid_preds = []
    valid_labels = []
    with torch.no_grad():
        for i, (x, y) in enumerate(valid_dataloader):
            y_pred = model(x[:,:dim_embeddings], x[:,dim_embeddings:])
            valid_preds.append(y_pred)
            valid_labels.append(y)
    valid_preds = torch.cat(valid_preds)
    valid_labels = torch.cat(valid_labels)
    valid_loss = mae_loss_function(valid_preds, valid_labels)
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), './AG_checkpoints/best_model.pth')
        print("Saving a new best model")
    scheduler.step(best_valid_loss)
    valid_recording.append(best_valid_loss.item())
    print(f'Epoch {epoch}, Validation Loss {valid_loss.item()}')
# Out:
# Epoch 0, Training Loss 1.5202254071557448
# Saving a new best model
# Epoch 0, Validation Loss 0.3910294771194458
# Epoch 1, Training Loss 0.40574746196499145
# Saving a new best model
# Epoch 1, Validation Loss 0.35130855441093445
# Epoch 2, Training Loss 0.37102817035525854
# Saving a new best model
# Epoch 2, Validation Loss 0.3508126437664032
# Epoch 3, Training Loss 0.36003783994291455
# Saving a new best model
# Epoch 3, Validation Loss 0.3373352885246277
# Epoch 4, Training Loss 0.3521557155470907
# Epoch 4, Validation Loss 0.3423433005809784
# Epoch 5, Training Loss 0.34818900742230974
# Epoch 5, Validation Loss 0.3378608226776123
# Epoch 6, Training Loss 0.3445480981639802
# Epoch 6, Validation Loss 0.34153681993484497
# Epoch 7, Training Loss 0.34211749332082786
# Saving a new best model
# Epoch 7, Validation Loss 0.3364161252975464
# Epoch 8, Training Loss 0.33910858460486787
# Saving a new best model
# Epoch 8, Validation Loss 0.3349840044975281
# Epoch 9, Training Loss 0.33819935725266703
# Epoch 9, Validation Loss 0.33549636602401733
# Epoch 10, Training Loss 0.3368948578590752
# Saving a new best model
# Epoch 10, Validation Loss 0.33412808179855347
# Epoch 11, Training Loss 0.33609420582195
# Epoch 11, Validation Loss 0.3377378582954407
# Epoch 12, Training Loss 0.3353652443683464
# Saving a new best model
# Epoch 12, Validation Loss 0.3334823250770569
# Epoch 13, Training Loss 0.33508970102405744
# Epoch 13, Validation Loss 0.33523744344711304
# Epoch 14, Training Loss 0.3329923517986797
# Saving a new best model
# Epoch 14, Validation Loss 0.33229243755340576
# Epoch 15, Training Loss 0.33141305168104074
# Epoch 15, Validation Loss 0.3324485421180725
# Epoch 16, Training Loss 0.3306371641701472
# Saving a new best model
# Epoch 16, Validation Loss 0.3315734267234802
# Epoch 17, Training Loss 0.33040435226721754
# Epoch 17, Validation Loss 0.3315960466861725
# Epoch 18, Training Loss 0.32849616235872475
# Epoch 18, Validation Loss 0.33556047081947327
# Epoch 19, Training Loss 0.3279571779270357
# Saving a new best model
# Epoch 19, Validation Loss 0.33005815744400024
# Epoch 20, Training Loss 0.3264992501137203
# Epoch 20, Validation Loss 0.3340887129306793
# Epoch 21, Training Loss 0.3256528067015919
# Epoch 21, Validation Loss 0.330211341381073
# Epoch 22, Training Loss 0.32487145211006724
# Epoch 22, Validation Loss 0.33112844824790955
# Epoch 23, Training Loss 0.32426635722928737
# Saving a new best model
# Epoch 23, Validation Loss 0.3287852704524994
# Epoch 24, Training Loss 0.322789904362463
# Epoch 24, Validation Loss 0.33055272698402405
# Epoch 25, Training Loss 0.32284049560260675
# Epoch 25, Validation Loss 0.33079347014427185
# Epoch 26, Training Loss 0.3210382844437607
# Epoch 26, Validation Loss 0.33046218752861023
# Epoch 27, Training Loss 0.32172446297234064
# Epoch 27, Validation Loss 0.3290623426437378
# Epoch 28, Training Loss 0.3203763614250595
# Epoch 28, Validation Loss 0.3293371796607971
# Epoch 29, Training Loss 0.3204541502859451
# Epoch 29, Validation Loss 0.3293473422527313
# Epoch 30, Training Loss 0.31796502026373136
# Epoch 30, Validation Loss 0.33073437213897705
# Epoch 31, Training Loss 0.31756243949226565
# Epoch 31, Validation Loss 0.33258551359176636
# Epoch 32, Training Loss 0.3163181792159997
# Epoch 32, Validation Loss 0.3324804902076721
# Epoch 33, Training Loss 0.3165238420259977
# Epoch 33, Validation Loss 0.3327445387840271
# Epoch 34, Training Loss 0.3165567770356537
# Epoch 34, Validation Loss 0.3348011076450348
# Epoch 35, Training Loss 0.31585729664576323
# Epoch 35, Validation Loss 0.3320316970348358
# Epoch 36, Training Loss 0.3143759338615618
# Saving a new best model
# Epoch 36, Validation Loss 0.3282146155834198
# Epoch 37, Training Loss 0.31421151211778564
# Epoch 37, Validation Loss 0.3290068805217743
# Epoch 38, Training Loss 0.3140760090179239
# Epoch 38, Validation Loss 0.3282569348812103
# Epoch 39, Training Loss 0.31374037093606705
# Saving a new best model
# Epoch 39, Validation Loss 0.32769936323165894
# Epoch 40, Training Loss 0.31337926475853034
# Epoch 40, Validation Loss 0.3282943367958069
# Epoch 41, Training Loss 0.3136567120232709
# Epoch 41, Validation Loss 0.32909107208251953
# Epoch 42, Training Loss 0.31354290048890804
# Epoch 42, Validation Loss 0.3281071186065674
# Epoch 43, Training Loss 0.3122326074080477
# Epoch 43, Validation Loss 0.32817134261131287
# Epoch 44, Training Loss 0.31247925849779984
# Epoch 44, Validation Loss 0.327959805727005
# Epoch 45, Training Loss 0.31349510903677813
# Epoch 45, Validation Loss 0.32819634675979614
# Epoch 46, Training Loss 0.31186240300505685
# Epoch 46, Validation Loss 0.32821735739707947
# Epoch 47, Training Loss 0.31110314532718286
# Epoch 47, Validation Loss 0.32968294620513916
# Epoch 48, Training Loss 0.3118420970494762
# Epoch 48, Validation Loss 0.32839855551719666
# Epoch 49, Training Loss 0.3109367388492957
# Saving a new best model
# Epoch 49, Validation Loss 0.32763728499412537
# Epoch 50, Training Loss 0.3102954578545927
# Epoch 50, Validation Loss 0.32797178626060486
# Epoch 51, Training Loss 0.3111307542687301
# Epoch 51, Validation Loss 0.32863447070121765
# Epoch 52, Training Loss 0.310608261552447
# Epoch 52, Validation Loss 0.32996538281440735
# Epoch 53, Training Loss 0.3106367267622538
# Saving a new best model
# Epoch 53, Validation Loss 0.3272411823272705
# Epoch 54, Training Loss 0.31060868059808733
# Saving a new best model
# Epoch 54, Validation Loss 0.32709115743637085
# Epoch 55, Training Loss 0.31106276660852883
# Epoch 55, Validation Loss 0.32767555117607117
# Epoch 56, Training Loss 0.3104548686334448
# Epoch 56, Validation Loss 0.32734817266464233
# Epoch 57, Training Loss 0.31080877866237927
# Epoch 57, Validation Loss 0.32948771119117737
# Epoch 58, Training Loss 0.3098241438620661
# Epoch 58, Validation Loss 0.32818102836608887
# Epoch 59, Training Loss 0.31010222476135735
# Epoch 59, Validation Loss 0.3288702666759491
# Epoch 60, Training Loss 0.31033204014437815
# Epoch 60, Validation Loss 0.32733193039894104
# Epoch 61, Training Loss 0.30960693015337964
# Epoch 61, Validation Loss 0.32761386036872864
# Epoch 62, Training Loss 0.30994922460527263
# Epoch 62, Validation Loss 0.32867786288261414
# Epoch 63, Training Loss 0.3085322558483707
# Epoch 63, Validation Loss 0.3271925449371338
# Epoch 64, Training Loss 0.3094488764467415
# Epoch 64, Validation Loss 0.3279648423194885
# Epoch 65, Training Loss 0.3092037687394273
# Epoch 65, Validation Loss 0.3300243616104126
# Epoch 66, Training Loss 0.30837645063249125
# Saving a new best model
# Epoch 66, Validation Loss 0.3270238935947418
# Epoch 67, Training Loss 0.30874048933722004
# Epoch 67, Validation Loss 0.3273254930973053
# Epoch 68, Training Loss 0.30808599235333795
# Saving a new best model
# Epoch 68, Validation Loss 0.3268376886844635
# Epoch 69, Training Loss 0.30836188983636886
# Epoch 69, Validation Loss 0.32751068472862244
# Epoch 70, Training Loss 0.3083654710516364
# Epoch 70, Validation Loss 0.32700785994529724
# Epoch 71, Training Loss 0.30819324533510306
# Epoch 71, Validation Loss 0.3273966312408447
# Epoch 72, Training Loss 0.30788711772313637
# Epoch 72, Validation Loss 0.3279680013656616
# Epoch 73, Training Loss 0.30754759205326226
# Epoch 73, Validation Loss 0.3279951512813568
# Epoch 74, Training Loss 0.3081838741502391
# Epoch 74, Validation Loss 0.32768121361732483
# Epoch 75, Training Loss 0.3074053393673068
# Epoch 75, Validation Loss 0.32698702812194824
# Epoch 76, Training Loss 0.3077506709744838
# Epoch 76, Validation Loss 0.3276730477809906
# Epoch 77, Training Loss 0.30773328093846153
# Epoch 77, Validation Loss 0.32740771770477295
# Epoch 78, Training Loss 0.30758020502718925
# Epoch 78, Validation Loss 0.32716527581214905
# Epoch 79, Training Loss 0.30723972571347147
# Epoch 79, Validation Loss 0.327757328748703
# Epoch 80, Training Loss 0.30749381327495007
# Epoch 80, Validation Loss 0.3274761140346527
# Epoch 81, Training Loss 0.30698182484123604
# Epoch 81, Validation Loss 0.3269651234149933
# Epoch 82, Training Loss 0.30801955019342875
# Epoch 82, Validation Loss 0.32696932554244995
# Epoch 83, Training Loss 0.3075403484281587
# Epoch 83, Validation Loss 0.3276371657848358
# Epoch 84, Training Loss 0.30696681179944235
# Epoch 84, Validation Loss 0.32714569568634033
# Epoch 85, Training Loss 0.30731353373980963
# Epoch 85, Validation Loss 0.3272877335548401
# Epoch 86, Training Loss 0.3076093390218319
# Epoch 86, Validation Loss 0.3270112872123718
# Epoch 87, Training Loss 0.30692668661383765
# Epoch 87, Validation Loss 0.3272145688533783
# Epoch 88, Training Loss 0.3073449223959373
# Epoch 88, Validation Loss 0.3274858295917511
# Epoch 89, Training Loss 0.3060105769973103
# Epoch 89, Validation Loss 0.3269028067588806
# Epoch 90, Training Loss 0.30726999119076503
# Epoch 90, Validation Loss 0.3273305594921112
# Epoch 91, Training Loss 0.30717693226590964
# Epoch 91, Validation Loss 0.3274451494216919
# Epoch 92, Training Loss 0.30712343909318707
# Epoch 92, Validation Loss 0.32726648449897766
# Epoch 93, Training Loss 0.3068603406410763
# Epoch 93, Validation Loss 0.32746216654777527
# Epoch 94, Training Loss 0.30696140862010984
# Epoch 94, Validation Loss 0.32742223143577576
# Epoch 95, Training Loss 0.3074965059818178
# Epoch 95, Validation Loss 0.3272131085395813
# Epoch 96, Training Loss 0.3072394629014782
# Epoch 96, Validation Loss 0.3272925019264221
# Epoch 97, Training Loss 0.3073988549243697
# Epoch 97, Validation Loss 0.32736364006996155
# Epoch 98, Training Loss 0.3072398607228675
# Epoch 98, Validation Loss 0.3270813524723053
# Epoch 99, Training Loss 0.3072130205776306
# Epoch 99, Validation Loss 0.32722002267837524

# %%
best_model = myDualmodel5(dim_embeddings,dim_numerical)
best_model.to(device)
best_model.load_state_dict(torch.load('./AG_checkpoints/best_model.pth'))

best_model.eval()
with torch.no_grad():
    test_preds = []
    test_labels = []
    for i, (x, y) in enumerate(test_dataloader):
        y_pred = best_model(x[:,:dim_embeddings], x[:,dim_embeddings:])
        test_preds.append(y_pred)
        test_labels.append(y)
    test_preds = torch.cat(test_preds)
    test_labels = torch.cat(test_labels)
    test_loss = mae_loss_function(test_preds, test_labels)
    print(f'Test Loss {round(test_loss.item(),3)}')
# Out:
# initialized Linear(in_features=512, out_features=32, bias=True)
# initialized Linear(in_features=9, out_features=32, bias=True)
# initialized Linear(in_features=64, out_features=32, bias=True)
# initialized Linear(in_features=32, out_features=1, bias=True)
# Test Loss 0.347
# <ipython-input-30-8a053dd51bee>:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_model.load_state_dict(torch.load('./AG_checkpoints/best_model.pth'))

# %% [markdown]
# ## Testing best model ever

# %%
best_model = myDualmodel5(dim_embeddings,dim_numerical)
best_model.to(device)
best_model.load_state_dict(torch.load('./AG_checkpoints/best_model.pth'))



best_model.eval()
with torch.no_grad():
    test_preds = []
    test_labels = []
    for i, (x, y) in enumerate(test_dataloader):
        y_pred = best_model(x[:,:dim_embeddings], x[:,dim_embeddings:])
        test_preds.append(y_pred)
        test_labels.append(y)
    test_preds = torch.cat(test_preds)
    test_labels = torch.cat(test_labels)
    test_loss = mae_loss_function(test_preds, test_labels)
    print(f'Test Loss {round(test_loss.item(),3)}')


#validation
best_model.eval()
with torch.no_grad():
    valid_preds = []
    valid_labels = []
    for i, (x, y) in enumerate(valid_dataloader):
        y_pred = best_model(x[:,:dim_embeddings], x[:,dim_embeddings:])
        valid_preds.append(y_pred)
        valid_labels.append(y)
    valid_preds = torch.cat(valid_preds)
    valid_labels = torch.cat(valid_labels)
    valid_loss = mae_loss_function(valid_preds, valid_labels)
    print(f'Valid Loss {round(valid_loss.item(),3)}')


#training
best_model.train()
with torch.no_grad():
    train_preds = []
    train_labels = []
    for i, (x, y) in enumerate(train_dataloader):
        y_pred = best_model(x[:,:dim_embeddings], x[:,dim_embeddings:])
        train_preds.append(y_pred)
        train_labels.append(y)
    train_preds = torch.cat(train_preds)
    train_labels = torch.cat(train_labels)
    train_loss = mae_loss_function(train_preds, train_labels)
    print(f'Train Loss {round(train_loss.item(),3)}')
# Out:
# initialized Linear(in_features=512, out_features=32, bias=True)
# initialized Linear(in_features=9, out_features=32, bias=True)
# initialized Linear(in_features=64, out_features=32, bias=True)
# initialized Linear(in_features=32, out_features=1, bias=True)
# Test Loss 0.347
# <ipython-input-32-29617fb2b802>:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_model.load_state_dict(torch.load('./AG_checkpoints/best_model.pth'))
# Valid Loss 0.327
# Train Loss 0.348

# %% [markdown]
# ## Dropout experiment results gathering

# %%
chosen_dr = [0,0.1,0.3,0.5,0.7]
num_epochs = 30
train_results = pd.DataFrame(index = np.arange(num_epochs))
valid_results = pd.DataFrame(index = np.arange(num_epochs))

# %%
for dr in chosen_dr:
  print(f"doing dropout rate {dr}")
  print('-'*50)

  #load the models and its hyperparams
  model = myDualmodel3(dim_embeddings,dim_numerical,drop_rate=dr)
  model.to(device)
  best_valid_loss = 5
  optimizer = optim.Adam(model.parameters(), lr=0.0015)
  scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, verbose=True)
  epochs = num_epochs
  my_training_loader = train_dataloader

  #initiating our lists for recording
  train_recording = []
  valid_recording =[]

  #train
  for epoch in range(epochs):
      model.train()
      train_loss = 0
      for i, (x, y) in enumerate(my_training_loader):
          optimizer.zero_grad()
          y_pred = model(x[:,:dim_embeddings], x[:,dim_embeddings:])
          loss = mae_loss_function(y_pred, y)
          train_loss += loss.item()
          loss.backward()
          optimizer.step()
          # if i % 10000 == 0:
      train_loss /= len(my_training_loader)
      train_recording.append(train_loss)
      print(f'Epoch {epoch}, Training Loss {train_loss}')

      model.eval()
      valid_preds = []
      valid_labels = []
      with torch.no_grad():
          for i, (x, y) in enumerate(valid_dataloader):
              y_pred = model(x[:,:dim_embeddings], x[:,dim_embeddings:])
              valid_preds.append(y_pred)
              valid_labels.append(y)
      valid_preds = torch.cat(valid_preds)
      valid_labels = torch.cat(valid_labels)
      valid_loss = mae_loss_function(valid_preds, valid_labels)
      if valid_loss < best_valid_loss:
          best_valid_loss = valid_loss
          torch.save(model.state_dict(), './AG_checkpoints/best_model.pth')
          print("Saving a new best model")
      scheduler.step(best_valid_loss)
      valid_recording.append(best_valid_loss.item())
      print(f'Epoch {epoch}, Validation Loss {valid_loss.item()}')

  #populating the dataframes
  train_results[str(dr)] = train_recording
  valid_results[str(dr)] = valid_recording
# Out:
# doing dropout rate 0
# --------------------------------------------------
# initialized Linear(in_features=512, out_features=32, bias=True)
# initialized Linear(in_features=9, out_features=32, bias=True)
# initialized Linear(in_features=64, out_features=32, bias=True)
# initialized Linear(in_features=32, out_features=1, bias=True)
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 0, Training Loss 0.6325349856495613
# Saving a new best model
# Epoch 0, Validation Loss 0.4965791404247284
# Epoch 1, Training Loss 0.4174899172136876
# Saving a new best model
# Epoch 1, Validation Loss 0.3955647647380829
# Epoch 2, Training Loss 0.39557726943297866
# Saving a new best model
# Epoch 2, Validation Loss 0.37607163190841675
# Epoch 3, Training Loss 0.37995777426931265
# Epoch 3, Validation Loss 0.42486509680747986
# Epoch 4, Training Loss 0.38252044239049066
# Epoch 4, Validation Loss 0.4446166455745697
# Epoch 5, Training Loss 0.3778694518565644
# Epoch 5, Validation Loss 0.41750410199165344
# Epoch 6, Training Loss 0.3678942091290692
# Epoch 6, Validation Loss 0.4219253659248352
# Epoch 7, Training Loss 0.3661458725852469
# Epoch 7, Validation Loss 0.4265061020851135
# Epoch 8, Training Loss 0.35839695238140706
# Epoch 8, Validation Loss 0.43299445509910583
# Epoch 9, Training Loss 0.3461207546948899
# Saving a new best model
# Epoch 9, Validation Loss 0.3550279140472412
# Epoch 10, Training Loss 0.33769663312074355
# Epoch 10, Validation Loss 0.36176159977912903
# Epoch 11, Training Loss 0.33395682049797115
# Saving a new best model
# Epoch 11, Validation Loss 0.3481599986553192
# Epoch 12, Training Loss 0.3367128688651604
# Epoch 12, Validation Loss 0.3547198176383972
# Epoch 13, Training Loss 0.3308820617680413
# Epoch 13, Validation Loss 0.37100985646247864
# Epoch 14, Training Loss 0.33064174123397877
# Saving a new best model
# Epoch 14, Validation Loss 0.33861106634140015
# Epoch 15, Training Loss 0.33366779832203697
# Saving a new best model
# Epoch 15, Validation Loss 0.3372035622596741
# Epoch 16, Training Loss 0.32660345257791273
# Epoch 16, Validation Loss 0.3446354269981384
# Epoch 17, Training Loss 0.3198045185311928
# Epoch 17, Validation Loss 0.3505330979824066
# Epoch 18, Training Loss 0.32553837044594963
# Epoch 18, Validation Loss 0.3516380488872528
# Epoch 19, Training Loss 0.318794003750649
# Epoch 19, Validation Loss 0.3433453440666199
# Epoch 20, Training Loss 0.3220154563067881
# Epoch 20, Validation Loss 0.35409116744995117
# Epoch 21, Training Loss 0.3206816943236655
# Epoch 21, Validation Loss 0.3420311212539673
# Epoch 22, Training Loss 0.3061648712080193
# Saving a new best model
# Epoch 22, Validation Loss 0.3330644369125366
# Epoch 23, Training Loss 0.3042214754321336
# Saving a new best model
# Epoch 23, Validation Loss 0.32888779044151306
# Epoch 24, Training Loss 0.30262171757428435
# Epoch 24, Validation Loss 0.3325425088405609
# Epoch 25, Training Loss 0.30266822522586107
# Epoch 25, Validation Loss 0.3317567706108093
# Epoch 26, Training Loss 0.30035088835988794
# Epoch 26, Validation Loss 0.3316076695919037
# Epoch 27, Training Loss 0.2997895879766205
# Epoch 27, Validation Loss 0.3296026289463043
# Epoch 28, Training Loss 0.29802680149643945
# Epoch 28, Validation Loss 0.33308589458465576
# Epoch 29, Training Loss 0.2971315181115166
# Epoch 29, Validation Loss 0.3299044072628021
# doing dropout rate 0.1
# --------------------------------------------------
# initialized Linear(in_features=512, out_features=32, bias=True)
# initialized Linear(in_features=9, out_features=32, bias=True)
# initialized Linear(in_features=64, out_features=32, bias=True)
# initialized Linear(in_features=32, out_features=1, bias=True)
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 0, Training Loss 1.1702557227484776
# Saving a new best model
# Epoch 0, Validation Loss 0.36298882961273193
# Epoch 1, Training Loss 0.3944293512583754
# Saving a new best model
# Epoch 1, Validation Loss 0.3531750738620758
# Epoch 2, Training Loss 0.38297799851265424
# Epoch 2, Validation Loss 0.35537591576576233
# Epoch 3, Training Loss 0.380289577831398
# Saving a new best model
# Epoch 3, Validation Loss 0.3483071029186249
# Epoch 4, Training Loss 0.37853303949342915
# Epoch 4, Validation Loss 0.3557131290435791
# Epoch 5, Training Loss 0.37831311381911453
# Saving a new best model
# Epoch 5, Validation Loss 0.33821117877960205
# Epoch 6, Training Loss 0.37435484130567814
# Epoch 6, Validation Loss 0.34517523646354675
# Epoch 7, Training Loss 0.3763316992388425
# Epoch 7, Validation Loss 0.35057333111763
# Epoch 8, Training Loss 0.3729814965818801
# Epoch 8, Validation Loss 0.35785090923309326
# Epoch 9, Training Loss 0.37243408167350023
# Epoch 9, Validation Loss 0.3431842029094696
# Epoch 10, Training Loss 0.37283462641002696
# Epoch 10, Validation Loss 0.3487841784954071
# Epoch 11, Training Loss 0.37040800235571303
# Epoch 11, Validation Loss 0.34544679522514343
# Epoch 12, Training Loss 0.3663115820757938
# Saving a new best model
# Epoch 12, Validation Loss 0.33806368708610535
# Epoch 13, Training Loss 0.36674578906873007
# Saving a new best model
# Epoch 13, Validation Loss 0.3320464789867401
# Epoch 14, Training Loss 0.36534487154403344
# Epoch 14, Validation Loss 0.3364584743976593
# Epoch 15, Training Loss 0.36384601383669973
# Saving a new best model
# Epoch 15, Validation Loss 0.32976233959198
# Epoch 16, Training Loss 0.36408633245098077
# Epoch 16, Validation Loss 0.33443018794059753
# Epoch 17, Training Loss 0.3630536247677111
# Epoch 17, Validation Loss 0.3342110514640808
# Epoch 18, Training Loss 0.3631614096508436
# Epoch 18, Validation Loss 0.3308238983154297
# Epoch 19, Training Loss 0.36240848318382274
# Epoch 19, Validation Loss 0.3352981209754944
# Epoch 20, Training Loss 0.36031343640115854
# Epoch 20, Validation Loss 0.33240973949432373
# Epoch 21, Training Loss 0.36152489515352837
# Epoch 21, Validation Loss 0.33230939507484436
# Epoch 22, Training Loss 0.36031692772189533
# Epoch 22, Validation Loss 0.3377687633037567
# Epoch 23, Training Loss 0.35915415205350926
# Epoch 23, Validation Loss 0.33347955346107483
# Epoch 24, Training Loss 0.3588514642633787
# Epoch 24, Validation Loss 0.33582186698913574
# Epoch 25, Training Loss 0.3583132128530241
# Epoch 25, Validation Loss 0.3383060395717621
# Epoch 26, Training Loss 0.35684225851468027
# Epoch 26, Validation Loss 0.33054637908935547
# Epoch 27, Training Loss 0.3594961412906159
# Epoch 27, Validation Loss 0.3347662091255188
# Epoch 28, Training Loss 0.35782133236314134
# Epoch 28, Validation Loss 0.3438234031200409
# Epoch 29, Training Loss 0.357747851004386
# Epoch 29, Validation Loss 0.3458282947540283
# doing dropout rate 0.3
# --------------------------------------------------
# initialized Linear(in_features=512, out_features=32, bias=True)
# initialized Linear(in_features=9, out_features=32, bias=True)
# initialized Linear(in_features=64, out_features=32, bias=True)
# initialized Linear(in_features=32, out_features=1, bias=True)
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 0, Training Loss 1.405675346195576
# Saving a new best model
# Epoch 0, Validation Loss 0.3496880829334259
# Epoch 1, Training Loss 0.4536055251498895
# Epoch 1, Validation Loss 0.38400447368621826
# Epoch 2, Training Loss 0.44189240852016615
# Epoch 2, Validation Loss 0.37217652797698975
# Epoch 3, Training Loss 0.4388245259752547
# Saving a new best model
# Epoch 3, Validation Loss 0.347782164812088
# Epoch 4, Training Loss 0.43459464085492133
# Epoch 4, Validation Loss 0.361983060836792
# Epoch 5, Training Loss 0.4349367919936014
# Epoch 5, Validation Loss 0.35247620940208435
# Epoch 6, Training Loss 0.4322215696541566
# Epoch 6, Validation Loss 0.348047137260437
# Epoch 7, Training Loss 0.4310197805212563
# Saving a new best model
# Epoch 7, Validation Loss 0.346542626619339
# Epoch 8, Training Loss 0.43162898545616246
# Epoch 8, Validation Loss 0.35078004002571106
# Epoch 9, Training Loss 0.43074689552584067
# Epoch 9, Validation Loss 0.349194198846817
# Epoch 10, Training Loss 0.430480010883696
# Epoch 10, Validation Loss 0.3641054630279541
# Epoch 11, Training Loss 0.43058443008512565
# Epoch 11, Validation Loss 0.36671537160873413
# Epoch 12, Training Loss 0.4278435593124304
# Epoch 12, Validation Loss 0.36812159419059753
# Epoch 13, Training Loss 0.42824889222780865
# Epoch 13, Validation Loss 0.36461785435676575
# Epoch 14, Training Loss 0.42353154295305045
# Saving a new best model
# Epoch 14, Validation Loss 0.3447198271751404
# Epoch 15, Training Loss 0.42296532863000663
# Saving a new best model
# Epoch 15, Validation Loss 0.33690598607063293
# Epoch 16, Training Loss 0.42499244219198795
# Epoch 16, Validation Loss 0.3409232795238495
# Epoch 17, Training Loss 0.4234207178978345
# Saving a new best model
# Epoch 17, Validation Loss 0.3312737047672272
# Epoch 18, Training Loss 0.4235336824733543
# Epoch 18, Validation Loss 0.34093600511550903
# Epoch 19, Training Loss 0.42432195155410923
# Epoch 19, Validation Loss 0.3452044427394867
# Epoch 20, Training Loss 0.42388857233743726
# Epoch 20, Validation Loss 0.33891257643699646
# Epoch 21, Training Loss 0.423776476051666
# Epoch 21, Validation Loss 0.3513334095478058
# Epoch 22, Training Loss 0.4167480183830047
# Epoch 22, Validation Loss 0.335438072681427
# Epoch 23, Training Loss 0.40987746996504154
# Epoch 23, Validation Loss 0.3397275507450104
# Epoch 24, Training Loss 0.4087829799800807
# Epoch 24, Validation Loss 0.35209891200065613
# Epoch 25, Training Loss 0.4084228997276848
# Epoch 25, Validation Loss 0.33816006779670715
# Epoch 26, Training Loss 0.40801318553571564
# Epoch 26, Validation Loss 0.34659087657928467
# Epoch 27, Training Loss 0.4093998902475419
# Epoch 27, Validation Loss 0.3474544882774353
# Epoch 28, Training Loss 0.4077584941877178
# Epoch 28, Validation Loss 0.35200488567352295
# Epoch 29, Training Loss 0.40783666766006765
# Epoch 29, Validation Loss 0.3614654541015625
# doing dropout rate 0.5
# --------------------------------------------------
# initialized Linear(in_features=512, out_features=32, bias=True)
# initialized Linear(in_features=9, out_features=32, bias=True)
# initialized Linear(in_features=64, out_features=32, bias=True)
# initialized Linear(in_features=32, out_features=1, bias=True)
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 0, Training Loss 2.5568195060352608
# Saving a new best model
# Epoch 0, Validation Loss 0.38506606221199036
# Epoch 1, Training Loss 0.5193821200015355
# Epoch 1, Validation Loss 0.3981247842311859
# Epoch 2, Training Loss 0.49437152668986095
# Epoch 2, Validation Loss 0.4437078833580017
# Epoch 3, Training Loss 0.4847427411557219
# Epoch 3, Validation Loss 0.4170193076133728
# Epoch 4, Training Loss 0.4820701071577326
# Epoch 4, Validation Loss 0.4215184450149536
# Epoch 5, Training Loss 0.47279399992985716
# Saving a new best model
# Epoch 5, Validation Loss 0.372670441865921
# Epoch 6, Training Loss 0.470936687598443
# Epoch 6, Validation Loss 0.4095340371131897
# Epoch 7, Training Loss 0.47148287704629643
# Epoch 7, Validation Loss 0.4066239297389984
# Epoch 8, Training Loss 0.4676756662581352
# Saving a new best model
# Epoch 8, Validation Loss 0.36551621556282043
# Epoch 9, Training Loss 0.4675393149043397
# Epoch 9, Validation Loss 0.36647894978523254
# Epoch 10, Training Loss 0.4685049998309227
# Epoch 10, Validation Loss 0.4180402457714081
# Epoch 11, Training Loss 0.4660121554733542
# Epoch 11, Validation Loss 0.39914804697036743
# Epoch 12, Training Loss 0.4696331621740006
# Epoch 12, Validation Loss 0.4197223484516144
# Epoch 13, Training Loss 0.46798207764732813
# Epoch 13, Validation Loss 0.37573760747909546
# Epoch 14, Training Loss 0.46910290919808034
# Epoch 14, Validation Loss 0.3987239897251129
# Epoch 15, Training Loss 0.4593473854179519
# Saving a new best model
# Epoch 15, Validation Loss 0.36068421602249146
# Epoch 16, Training Loss 0.4624800105828693
# Saving a new best model
# Epoch 16, Validation Loss 0.3590661287307739
# Epoch 17, Training Loss 0.4599931959238033
# Epoch 17, Validation Loss 0.3593989610671997
# Epoch 18, Training Loss 0.46182916912198796
# Epoch 18, Validation Loss 0.368132084608078
# Epoch 19, Training Loss 0.45964251973633874
# Epoch 19, Validation Loss 0.36824434995651245
# Epoch 20, Training Loss 0.46032526403482704
# Epoch 20, Validation Loss 0.3762439489364624
# Epoch 21, Training Loss 0.4594896722181199
# Saving a new best model
# Epoch 21, Validation Loss 0.3500537574291229
# Epoch 22, Training Loss 0.45943153763841266
# Epoch 22, Validation Loss 0.36901551485061646
# Epoch 23, Training Loss 0.4605456933165864
# Epoch 23, Validation Loss 0.37506982684135437
# Epoch 24, Training Loss 0.4593678874959731
# Epoch 24, Validation Loss 0.3602670133113861
# Epoch 25, Training Loss 0.45956104308183937
# Epoch 25, Validation Loss 0.3657829463481903
# Epoch 26, Training Loss 0.4572081336397335
# Epoch 26, Validation Loss 0.3875565528869629
# Epoch 27, Training Loss 0.4582413782980788
# Epoch 27, Validation Loss 0.3606325089931488
# Epoch 28, Training Loss 0.4571808830116912
# Epoch 28, Validation Loss 0.3622017204761505
# Epoch 29, Training Loss 0.458101198717129
# Saving a new best model
# Epoch 29, Validation Loss 0.34968873858451843
# doing dropout rate 0.7
# --------------------------------------------------
# initialized Linear(in_features=512, out_features=32, bias=True)
# initialized Linear(in_features=9, out_features=32, bias=True)
# initialized Linear(in_features=64, out_features=32, bias=True)
# initialized Linear(in_features=32, out_features=1, bias=True)
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 0, Training Loss 5.869405160530457
# Saving a new best model
# Epoch 0, Validation Loss 0.4676188826560974
# Epoch 1, Training Loss 0.6660302631206552
# Epoch 1, Validation Loss 0.47001758217811584
# Epoch 2, Training Loss 0.6278243145328358
# Epoch 2, Validation Loss 0.5532776117324829
# Epoch 3, Training Loss 0.6046063870130629
# Saving a new best model
# Epoch 3, Validation Loss 0.45388346910476685
# Epoch 4, Training Loss 0.586269042730819
# Epoch 4, Validation Loss 0.4744335114955902
# Epoch 5, Training Loss 0.5792560621273298
# Epoch 5, Validation Loss 0.4993826448917389
# Epoch 6, Training Loss 0.5736806837571423
# Saving a new best model
# Epoch 6, Validation Loss 0.4255141615867615
# Epoch 7, Training Loss 0.571100195431758
# Epoch 7, Validation Loss 0.4857250154018402
# Epoch 8, Training Loss 0.5640749069566863
# Epoch 8, Validation Loss 0.45575833320617676
# Epoch 9, Training Loss 0.5669764809325673
# Epoch 9, Validation Loss 0.4369828999042511
# Epoch 10, Training Loss 0.5628135263432267
# Epoch 10, Validation Loss 0.43884700536727905
# Epoch 11, Training Loss 0.5629037375464762
# Epoch 11, Validation Loss 0.4480609595775604
# Epoch 12, Training Loss 0.5633011001994517
# Epoch 12, Validation Loss 0.4614103138446808
# Epoch 13, Training Loss 0.5564338564263287
# Saving a new best model
# Epoch 13, Validation Loss 0.41456881165504456
# Epoch 14, Training Loss 0.5557641928181326
# Epoch 14, Validation Loss 0.43088865280151367
# Epoch 15, Training Loss 0.5537941134658572
# Epoch 15, Validation Loss 0.4157612919807434
# Epoch 16, Training Loss 0.5564728273813954
# Saving a new best model
# Epoch 16, Validation Loss 0.4106947183609009
# Epoch 17, Training Loss 0.5544560666830262
# Epoch 17, Validation Loss 0.4369431436061859
# Epoch 18, Training Loss 0.5568901476562632
# Epoch 18, Validation Loss 0.4374428987503052
# Epoch 19, Training Loss 0.5529544764257404
# Epoch 19, Validation Loss 0.4347561001777649
# Epoch 20, Training Loss 0.5530338194106985
# Saving a new best model
# Epoch 20, Validation Loss 0.4102327525615692
# Epoch 21, Training Loss 0.5546922451513676
# Epoch 21, Validation Loss 0.4321316182613373
# Epoch 22, Training Loss 0.5549437882100634
# Saving a new best model
# Epoch 22, Validation Loss 0.3883671164512634
# Epoch 23, Training Loss 0.5535227218166695
# Saving a new best model
# Epoch 23, Validation Loss 0.38553592562675476
# Epoch 24, Training Loss 0.5541065195708674
# Epoch 24, Validation Loss 0.3969127833843231
# Epoch 25, Training Loss 0.553827490238568
# Epoch 25, Validation Loss 0.4298112690448761
# Epoch 26, Training Loss 0.5513808399377913
# Epoch 26, Validation Loss 0.4105801284313202
# Epoch 27, Training Loss 0.5544892437984607
# Epoch 27, Validation Loss 0.4470360577106476
# Epoch 28, Training Loss 0.5511601910391224
# Epoch 28, Validation Loss 0.3909642696380615
# Epoch 29, Training Loss 0.5556354529409077
# Epoch 29, Validation Loss 0.40125784277915955

# %%
train_results.tail(2)
# Out:
#            0       0.1       0.3       0.5       0.7
# 28  0.298027  0.357821  0.407758  0.457181  0.551160
# 29  0.297132  0.357748  0.407837  0.458101  0.555635

# %%
valid_results.tail(2)
# Out:
#            0       0.1       0.3       0.5       0.7
# 28  0.328888  0.329762  0.331274  0.350054  0.385536
# 29  0.328888  0.329762  0.331274  0.349689  0.385536

# %%
train_results.to_pickle('./train_results2.pkl')
valid_results.to_pickle('./valid_results2.pkl')

# %%
# #test loss
# test_losses_dr = [0.38685,0.3915,0.3912]
# dr = [0.1,0.3,0.5,0.7]

# %% [markdown]
# ## Running Batchsize experiment

# %%
bs_sizes = [32,64,128,256,512,1024]
bs_df  = pd.DataFrame(index = bs_sizes, columns=['train_loss','valid_loss','test_loss'])

# %%
for bs in bs_sizes:
    print(f'STARTING WITH BATCH SIZE {bs}')
    print("--"*50)

    #Making the dataloader
    train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=bs, shuffle=False)
    valid_dataloader = torch.utils.data.DataLoader(valid_dataset, batch_size=bs, shuffle=False)
    test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=bs, shuffle=False)

    #initiating the model and optimizer
    model = myDualmodel5(dim_embeddings,dim_numerical,drop_rate=0.1)
    model.to(device)

    best_valid_loss = 5
    optimizer = optim.Adam(model.parameters(), lr=0.0015* (bs/128))
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, verbose=True)
    epochs = 30
    my_training_loader = train_dataloader

    #training
    for epoch in range(epochs):
        model.train()
        train_loss = 0
        for i, (x, y) in enumerate(my_training_loader):
            optimizer.zero_grad()
            y_pred = model(x[:,:dim_embeddings], x[:,dim_embeddings:])
            loss = mae_loss_function(y_pred, y)
            train_loss += loss.item()
            loss.backward()
            optimizer.step()
            # if i % 10000 == 0:
        train_loss /= len(my_training_loader)
        print(f'Epoch {epoch}, Training Loss {train_loss}')

        model.eval()
        valid_preds = []
        valid_labels = []
        with torch.no_grad():
            for i, (x, y) in enumerate(valid_dataloader):
                y_pred = model(x[:,:dim_embeddings], x[:,dim_embeddings:])
                valid_preds.append(y_pred)
                valid_labels.append(y)
        valid_preds = torch.cat(valid_preds)
        valid_labels = torch.cat(valid_labels)
        valid_loss = mae_loss_function(valid_preds, valid_labels)
        if valid_loss < best_valid_loss:
            best_valid_loss = valid_loss
            torch.save(model.state_dict(), f'./AG_checkpoints/best_model_bs2_{str(bs)}.pth')
            print("Saving a new best model")
        scheduler.step(best_valid_loss)
        print(f'Epoch {epoch}, Validation Loss {valid_loss.item()}')


    #evaluation
    best_model = myDualmodel5(dim_embeddings,dim_numerical)
    best_model.to(device)

    best_model.load_state_dict(torch.load(f'./AG_checkpoints/best_model_bs2_{str(bs)}.pth'))
    best_model.eval()
    with torch.no_grad():
        test_preds = []
        test_labels = []
        for i, (x, y) in enumerate(test_dataloader):
            y_pred = best_model(x[:,:dim_embeddings], x[:,dim_embeddings:])
            test_preds.append(y_pred)
            test_labels.append(y)
        test_preds = torch.cat(test_preds)
        test_labels = torch.cat(test_labels)
        test_loss = mae_loss_function(test_preds, test_labels)
        print(f'Test Loss {test_loss.item()}')

    #recording
    bs_df.loc[bs,'train_loss'] = train_loss
    bs_df.loc[bs,'valid_loss'] = valid_loss.item()
    bs_df.loc[bs,'test_loss'] = test_loss.item()
# Out:
# STARTING WITH BATCH SIZE 32
# ----------------------------------------------------------------------------------------------------
# initialized Linear(in_features=512, out_features=32, bias=True)
# initialized Linear(in_features=9, out_features=32, bias=True)
# initialized Linear(in_features=64, out_features=32, bias=True)
# initialized Linear(in_features=32, out_features=1, bias=True)
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 0, Training Loss 1.0349548010303236
# Saving a new best model
# Epoch 0, Validation Loss 0.3630901277065277
# Epoch 1, Training Loss 0.40797450280822145
# Saving a new best model
# Epoch 1, Validation Loss 0.3504640460014343
# Epoch 2, Training Loss 0.3714826003174343
# Epoch 2, Validation Loss 0.3598935604095459
# Epoch 3, Training Loss 0.35380273364065096
# Saving a new best model
# Epoch 3, Validation Loss 0.34126463532447815
# Epoch 4, Training Loss 0.34276575233758716
# Epoch 4, Validation Loss 0.3471960127353668
# Epoch 5, Training Loss 0.3376841849063897
# Saving a new best model
# Epoch 5, Validation Loss 0.33573079109191895
# Epoch 6, Training Loss 0.3328779936284589
# Saving a new best model
# Epoch 6, Validation Loss 0.33557596802711487
# Epoch 7, Training Loss 0.33109096046680075
# Epoch 7, Validation Loss 0.3362908661365509
# Epoch 8, Training Loss 0.32905256498004776
# Epoch 8, Validation Loss 0.3407595753669739
# Epoch 9, Training Loss 0.3267781442645794
# Epoch 9, Validation Loss 0.3359006345272064
# Epoch 10, Training Loss 0.32586537272671756
# Epoch 10, Validation Loss 0.3468448519706726
# Epoch 11, Training Loss 0.3242574989547967
# Saving a new best model
# Epoch 11, Validation Loss 0.33431997895240784
# Epoch 12, Training Loss 0.3225844177438894
# Epoch 12, Validation Loss 0.33841976523399353
# Epoch 13, Training Loss 0.3224408811258386
# Epoch 13, Validation Loss 0.33533045649528503
# Epoch 14, Training Loss 0.32168301596399157
# Epoch 14, Validation Loss 0.3358295261859894
# Epoch 15, Training Loss 0.32091938494930944
# Epoch 15, Validation Loss 0.3373457193374634
# Epoch 16, Training Loss 0.32088501814876674
# Epoch 16, Validation Loss 0.335353821516037
# Epoch 17, Training Loss 0.3189268970771519
# Saving a new best model
# Epoch 17, Validation Loss 0.33366525173187256
# Epoch 18, Training Loss 0.31933343016144716
# Epoch 18, Validation Loss 0.3340129852294922
# Epoch 19, Training Loss 0.31878023218087226
# Epoch 19, Validation Loss 0.352093905210495
# Epoch 20, Training Loss 0.31802563688448626
# Epoch 20, Validation Loss 0.3362444341182709
# Epoch 21, Training Loss 0.31803986832137454
# Epoch 21, Validation Loss 0.33915120363235474
# Epoch 22, Training Loss 0.31784568795376955
# Saving a new best model
# Epoch 22, Validation Loss 0.33180639147758484
# Epoch 23, Training Loss 0.316738570774036
# Epoch 23, Validation Loss 0.33276328444480896
# Epoch 24, Training Loss 0.3164658147241453
# Epoch 24, Validation Loss 0.33346498012542725
# Epoch 25, Training Loss 0.31606371045455606
# Epoch 25, Validation Loss 0.33197399973869324
# Epoch 26, Training Loss 0.3156152676381266
# Epoch 26, Validation Loss 0.3355183005332947
# Epoch 27, Training Loss 0.3157516076827369
# Epoch 27, Validation Loss 0.3347395956516266
# Epoch 28, Training Loss 0.31580386475119215
# Epoch 28, Validation Loss 0.33930495381355286
# Epoch 29, Training Loss 0.3117041123969018
# Saving a new best model
# Epoch 29, Validation Loss 0.3311522603034973
# initialized Linear(in_features=512, out_features=32, bias=True)
# initialized Linear(in_features=9, out_features=32, bias=True)
# initialized Linear(in_features=64, out_features=32, bias=True)
# initialized Linear(in_features=32, out_features=1, bias=True)
# <ipython-input-23-564ae35afd53>:58: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_model.load_state_dict(torch.load(f'./AG_checkpoints/best_model_bs2_{str(bs)}.pth'))
# Test Loss 0.35068660974502563
# STARTING WITH BATCH SIZE 64
# ----------------------------------------------------------------------------------------------------
# initialized Linear(in_features=512, out_features=32, bias=True)
# initialized Linear(in_features=9, out_features=32, bias=True)
# initialized Linear(in_features=64, out_features=32, bias=True)
# initialized Linear(in_features=32, out_features=1, bias=True)
# Epoch 0, Training Loss 0.9353209448211334
# Saving a new best model
# Epoch 0, Validation Loss 0.360471248626709
# Epoch 1, Training Loss 0.39581731062792147
# Saving a new best model
# Epoch 1, Validation Loss 0.3543114960193634
# Epoch 2, Training Loss 0.3747598690488149
# Saving a new best model
# Epoch 2, Validation Loss 0.34288033843040466
# Epoch 3, Training Loss 0.3625934260656767
# Epoch 3, Validation Loss 0.35596439242362976
# Epoch 4, Training Loss 0.35425072055491036
# Epoch 4, Validation Loss 0.3511887490749359
# Epoch 5, Training Loss 0.3487266976090953
# Saving a new best model
# Epoch 5, Validation Loss 0.3421356678009033
# Epoch 6, Training Loss 0.3434425333538629
# Saving a new best model
# Epoch 6, Validation Loss 0.3353186845779419
# Epoch 7, Training Loss 0.3383425847534329
# Epoch 7, Validation Loss 0.3361037075519562
# Epoch 8, Training Loss 0.3336816585353573
# Saving a new best model
# Epoch 8, Validation Loss 0.33350062370300293
# Epoch 9, Training Loss 0.33096374056070965
# Epoch 9, Validation Loss 0.3358675539493561
# Epoch 10, Training Loss 0.3280766568620644
# Saving a new best model
# Epoch 10, Validation Loss 0.3313424587249756
# Epoch 11, Training Loss 0.3261211150347272
# Epoch 11, Validation Loss 0.33500492572784424
# Epoch 12, Training Loss 0.32447974679948727
# Saving a new best model
# Epoch 12, Validation Loss 0.330617755651474
# Epoch 13, Training Loss 0.3235543149949797
# Epoch 13, Validation Loss 0.3352355360984802
# Epoch 14, Training Loss 0.32206854562244147
# Epoch 14, Validation Loss 0.33209386467933655
# Epoch 15, Training Loss 0.3215443914160704
# Saving a new best model
# Epoch 15, Validation Loss 0.32996249198913574
# Epoch 16, Training Loss 0.3206292615922363
# Epoch 16, Validation Loss 0.3335515856742859
# Epoch 17, Training Loss 0.3201821505204034
# Epoch 17, Validation Loss 0.3300180435180664
# Epoch 18, Training Loss 0.31879135284696697
# Epoch 18, Validation Loss 0.33168575167655945
# Epoch 19, Training Loss 0.31861001733128375
# Epoch 19, Validation Loss 0.3381038010120392
# Epoch 20, Training Loss 0.31856181777232445
# Epoch 20, Validation Loss 0.3391871750354767
# Epoch 21, Training Loss 0.31842835518100376
# Epoch 21, Validation Loss 0.33103087544441223
# Epoch 22, Training Loss 0.3156035077255553
# Epoch 22, Validation Loss 0.33046579360961914
# Epoch 23, Training Loss 0.31533858240832147
# Saving a new best model
# Epoch 23, Validation Loss 0.32960817217826843
# Epoch 24, Training Loss 0.3147428006962742
# Epoch 24, Validation Loss 0.33107903599739075
# Epoch 25, Training Loss 0.3148800189747377
# Epoch 25, Validation Loss 0.3321841359138489
# Epoch 26, Training Loss 0.3130082167799363
# Epoch 26, Validation Loss 0.32977160811424255
# Epoch 27, Training Loss 0.3135703279958357
# Saving a new best model
# Epoch 27, Validation Loss 0.3281857669353485
# Epoch 28, Training Loss 0.3134934162011232
# Epoch 28, Validation Loss 0.33344897627830505
# Epoch 29, Training Loss 0.31301011170267756
# Epoch 29, Validation Loss 0.32851749658584595
# initialized Linear(in_features=512, out_features=32, bias=True)
# initialized Linear(in_features=9, out_features=32, bias=True)
# initialized Linear(in_features=64, out_features=32, bias=True)
# initialized Linear(in_features=32, out_features=1, bias=True)
# Test Loss 0.3496217429637909
# STARTING WITH BATCH SIZE 128
# ----------------------------------------------------------------------------------------------------
# initialized Linear(in_features=512, out_features=32, bias=True)
# initialized Linear(in_features=9, out_features=32, bias=True)
# initialized Linear(in_features=64, out_features=32, bias=True)
# initialized Linear(in_features=32, out_features=1, bias=True)
# Epoch 0, Training Loss 0.7601576905796621
# Saving a new best model
# Epoch 0, Validation Loss 0.3463563323020935
# Epoch 1, Training Loss 0.3825919142712845
# Epoch 1, Validation Loss 0.35456639528274536
# Epoch 2, Training Loss 0.3653632053126465
# Epoch 2, Validation Loss 0.3563455045223236
# Epoch 3, Training Loss 0.35723987836505006
# Epoch 3, Validation Loss 0.35298943519592285
# Epoch 4, Training Loss 0.35103532769441115
# Epoch 4, Validation Loss 0.3586764931678772
# Epoch 5, Training Loss 0.3463835142141471
# Saving a new best model
# Epoch 5, Validation Loss 0.34054625034332275
# Epoch 6, Training Loss 0.34294976444118835
# Saving a new best model
# Epoch 6, Validation Loss 0.3395521640777588
# Epoch 7, Training Loss 0.3386815595754816
# Saving a new best model
# Epoch 7, Validation Loss 0.3326375484466553
# Epoch 8, Training Loss 0.33631255025908746
# Epoch 8, Validation Loss 0.3383260667324066
# Epoch 9, Training Loss 0.33403357306537207
# Saving a new best model
# Epoch 9, Validation Loss 0.33072033524513245
# Epoch 10, Training Loss 0.3318431042134762
# Epoch 10, Validation Loss 0.3379088342189789
# Epoch 11, Training Loss 0.3299411753371571
# Epoch 11, Validation Loss 0.33321160078048706
# Epoch 12, Training Loss 0.32809156064393574
# Saving a new best model
# Epoch 12, Validation Loss 0.3306370973587036
# Epoch 13, Training Loss 0.3268063533555998
# Epoch 13, Validation Loss 0.3311271369457245
# Epoch 14, Training Loss 0.3254632367343015
# Epoch 14, Validation Loss 0.33126121759414673
# Epoch 15, Training Loss 0.3247271839734967
# Saving a new best model
# Epoch 15, Validation Loss 0.3299252390861511
# Epoch 16, Training Loss 0.3221356910796253
# Saving a new best model
# Epoch 16, Validation Loss 0.3296978771686554
# Epoch 17, Training Loss 0.321945494806474
# Saving a new best model
# Epoch 17, Validation Loss 0.3287641704082489
# Epoch 18, Training Loss 0.320160277431606
# Epoch 18, Validation Loss 0.32910284399986267
# Epoch 19, Training Loss 0.31924784936940254
# Epoch 19, Validation Loss 0.32949382066726685
# Epoch 20, Training Loss 0.318987453177358
# Epoch 20, Validation Loss 0.3298541009426117
# Epoch 21, Training Loss 0.3176738797917444
# Saving a new best model
# Epoch 21, Validation Loss 0.3286421000957489
# Epoch 22, Training Loss 0.31780808603349153
# Saving a new best model
# Epoch 22, Validation Loss 0.3281559348106384
# Epoch 23, Training Loss 0.31730296091007065
# Epoch 23, Validation Loss 0.33123087882995605
# Epoch 24, Training Loss 0.31640275455020933
# Epoch 24, Validation Loss 0.3311311602592468
# Epoch 25, Training Loss 0.31612799465961006
# Epoch 25, Validation Loss 0.32939350605010986
# Epoch 26, Training Loss 0.31591252433726513
# Epoch 26, Validation Loss 0.3296612799167633
# Epoch 27, Training Loss 0.3156904074951915
# Epoch 27, Validation Loss 0.33151790499687195
# Epoch 28, Training Loss 0.3153120901374668
# Epoch 28, Validation Loss 0.3299638330936432
# Epoch 29, Training Loss 0.3129688599480198
# Epoch 29, Validation Loss 0.32926857471466064
# initialized Linear(in_features=512, out_features=32, bias=True)
# initialized Linear(in_features=9, out_features=32, bias=True)
# initialized Linear(in_features=64, out_features=32, bias=True)
# initialized Linear(in_features=32, out_features=1, bias=True)
# Test Loss 0.34944412112236023
# STARTING WITH BATCH SIZE 256
# ----------------------------------------------------------------------------------------------------
# initialized Linear(in_features=512, out_features=32, bias=True)
# initialized Linear(in_features=9, out_features=32, bias=True)
# initialized Linear(in_features=64, out_features=32, bias=True)
# initialized Linear(in_features=32, out_features=1, bias=True)
# Epoch 0, Training Loss 0.7707557171156557
# Saving a new best model
# Epoch 0, Validation Loss 0.3512474298477173
# Epoch 1, Training Loss 0.37640256811017153
# Epoch 1, Validation Loss 0.36357447504997253
# Epoch 2, Training Loss 0.36485068109991114
# Saving a new best model
# Epoch 2, Validation Loss 0.341746985912323
# Epoch 3, Training Loss 0.3566243633140328
# Saving a new best model
# Epoch 3, Validation Loss 0.3361463248729706
# Epoch 4, Training Loss 0.34938027955027934
# Saving a new best model
# Epoch 4, Validation Loss 0.3360810875892639
# Epoch 5, Training Loss 0.3455789618971158
# Epoch 5, Validation Loss 0.339000940322876
# Epoch 6, Training Loss 0.34181858011062405
# Saving a new best model
# Epoch 6, Validation Loss 0.3346887230873108
# Epoch 7, Training Loss 0.3389276259546387
# Saving a new best model
# Epoch 7, Validation Loss 0.3344246447086334
# Epoch 8, Training Loss 0.336068374003857
# Saving a new best model
# Epoch 8, Validation Loss 0.33347007632255554
# Epoch 9, Training Loss 0.33474928989305575
# Saving a new best model
# Epoch 9, Validation Loss 0.3318606913089752
# Epoch 10, Training Loss 0.33407092390006793
# Epoch 10, Validation Loss 0.33294591307640076
# Epoch 11, Training Loss 0.3306471001973913
# Saving a new best model
# Epoch 11, Validation Loss 0.3310772180557251
# Epoch 12, Training Loss 0.3293551375407627
# Epoch 12, Validation Loss 0.33167675137519836
# Epoch 13, Training Loss 0.32821896227347097
# Epoch 13, Validation Loss 0.33553391695022583
# Epoch 14, Training Loss 0.3270699653340264
# Saving a new best model
# Epoch 14, Validation Loss 0.33030661940574646
# Epoch 15, Training Loss 0.32506887546163393
# Epoch 15, Validation Loss 0.3310833275318146
# Epoch 16, Training Loss 0.32470667925958496
# Epoch 16, Validation Loss 0.3320513367652893
# Epoch 17, Training Loss 0.32414523195208705
# Epoch 17, Validation Loss 0.33372440934181213
# Epoch 18, Training Loss 0.32385359405861797
# Epoch 18, Validation Loss 0.3313071131706238
# Epoch 19, Training Loss 0.323007280186032
# Epoch 19, Validation Loss 0.3318994343280792
# Epoch 20, Training Loss 0.3220402665573395
# Epoch 20, Validation Loss 0.3325263559818268
# Epoch 21, Training Loss 0.3188881960627004
# Epoch 21, Validation Loss 0.331481397151947
# Epoch 22, Training Loss 0.3191967191506017
# Saving a new best model
# Epoch 22, Validation Loss 0.3300968408584595
# Epoch 23, Training Loss 0.3180854819212223
# Epoch 23, Validation Loss 0.3322463035583496
# Epoch 24, Training Loss 0.31763692660321974
# Saving a new best model
# Epoch 24, Validation Loss 0.3297280967235565
# Epoch 25, Training Loss 0.3173816147239418
# Saving a new best model
# Epoch 25, Validation Loss 0.3284951448440552
# Epoch 26, Training Loss 0.3159456571796433
# Saving a new best model
# Epoch 26, Validation Loss 0.3284866511821747
# Epoch 27, Training Loss 0.31638413631111567
# Epoch 27, Validation Loss 0.3289949297904968
# Epoch 28, Training Loss 0.3164610281769483
# Saving a new best model
# Epoch 28, Validation Loss 0.3283788561820984
# Epoch 29, Training Loss 0.3163059476938228
# Epoch 29, Validation Loss 0.33091217279434204
# initialized Linear(in_features=512, out_features=32, bias=True)
# initialized Linear(in_features=9, out_features=32, bias=True)
# initialized Linear(in_features=64, out_features=32, bias=True)
# initialized Linear(in_features=32, out_features=1, bias=True)
# Test Loss 0.34648898243904114
# STARTING WITH BATCH SIZE 512
# ----------------------------------------------------------------------------------------------------
# initialized Linear(in_features=512, out_features=32, bias=True)
# initialized Linear(in_features=9, out_features=32, bias=True)
# initialized Linear(in_features=64, out_features=32, bias=True)
# initialized Linear(in_features=32, out_features=1, bias=True)
# Epoch 0, Training Loss 1.1240204398729363
# Saving a new best model
# Epoch 0, Validation Loss 0.36734291911125183
# Epoch 1, Training Loss 0.38866687666396704
# Saving a new best model
# Epoch 1, Validation Loss 0.35293784737586975
# Epoch 2, Training Loss 0.36691235036266096
# Saving a new best model
# Epoch 2, Validation Loss 0.3388734757900238
# Epoch 3, Training Loss 0.3567735910719755
# Epoch 3, Validation Loss 0.3489222228527069
# Epoch 4, Training Loss 0.3517307204859597
# Epoch 4, Validation Loss 0.3438299894332886
# Epoch 5, Training Loss 0.34649375436865554
# Epoch 5, Validation Loss 0.34012487530708313
# Epoch 6, Training Loss 0.34195568008082255
# Saving a new best model
# Epoch 6, Validation Loss 0.33863547444343567
# Epoch 7, Training Loss 0.3403984748283211
# Epoch 7, Validation Loss 0.3396241366863251
# Epoch 8, Training Loss 0.339782527606098
# Epoch 8, Validation Loss 0.3409162163734436
# Epoch 9, Training Loss 0.3392339241139743
# Epoch 9, Validation Loss 0.34125635027885437
# Epoch 10, Training Loss 0.33801687259455115
# Saving a new best model
# Epoch 10, Validation Loss 0.3378327190876007
# Epoch 11, Training Loss 0.336247310711413
# Saving a new best model
# Epoch 11, Validation Loss 0.3354816436767578
# Epoch 12, Training Loss 0.3350207440098938
# Epoch 12, Validation Loss 0.337642103433609
# Epoch 13, Training Loss 0.3347175124044321
# Epoch 13, Validation Loss 0.33648020029067993
# Epoch 14, Training Loss 0.3319190883210727
# Epoch 14, Validation Loss 0.33896660804748535
# Epoch 15, Training Loss 0.3321282465847171
# Saving a new best model
# Epoch 15, Validation Loss 0.33477917313575745
# Epoch 16, Training Loss 0.3319060115485775
# Epoch 16, Validation Loss 0.34067416191101074
# Epoch 17, Training Loss 0.331879219716909
# Epoch 17, Validation Loss 0.3366357684135437
# Epoch 18, Training Loss 0.32961830913412327
# Epoch 18, Validation Loss 0.343985915184021
# Epoch 19, Training Loss 0.3303935066473727
# Epoch 19, Validation Loss 0.3355713486671448
# Epoch 20, Training Loss 0.33053878269025255
# Epoch 20, Validation Loss 0.342155396938324
# Epoch 21, Training Loss 0.32965648712552326
# Epoch 21, Validation Loss 0.34096914529800415
# Epoch 22, Training Loss 0.3270735725152249
# Saving a new best model
# Epoch 22, Validation Loss 0.33438605070114136
# Epoch 23, Training Loss 0.32579279548051404
# Epoch 23, Validation Loss 0.33541765809059143
# Epoch 24, Training Loss 0.3243203857115337
# Saving a new best model
# Epoch 24, Validation Loss 0.3333764672279358
# Epoch 25, Training Loss 0.32483682124590385
# Epoch 25, Validation Loss 0.33466118574142456
# Epoch 26, Training Loss 0.32449317988084286
# Epoch 26, Validation Loss 0.33564212918281555
# Epoch 27, Training Loss 0.32392781732641923
# Epoch 27, Validation Loss 0.33662840723991394
# Epoch 28, Training Loss 0.3231236615959479
# Epoch 28, Validation Loss 0.33488011360168457
# Epoch 29, Training Loss 0.3234136523032675
# Saving a new best model
# Epoch 29, Validation Loss 0.33112192153930664
# initialized Linear(in_features=512, out_features=32, bias=True)
# initialized Linear(in_features=9, out_features=32, bias=True)
# initialized Linear(in_features=64, out_features=32, bias=True)
# initialized Linear(in_features=32, out_features=1, bias=True)
# Test Loss 0.35049358010292053
# STARTING WITH BATCH SIZE 1024
# ----------------------------------------------------------------------------------------------------
# initialized Linear(in_features=512, out_features=32, bias=True)
# initialized Linear(in_features=9, out_features=32, bias=True)
# initialized Linear(in_features=64, out_features=32, bias=True)
# initialized Linear(in_features=32, out_features=1, bias=True)
# Epoch 0, Training Loss 1.0901310000477769
# Saving a new best model
# Epoch 0, Validation Loss 0.36747458577156067
# Epoch 1, Training Loss 0.3838702899411442
# Saving a new best model
# Epoch 1, Validation Loss 0.3532998859882355
# Epoch 2, Training Loss 0.3657428908154247
# Epoch 2, Validation Loss 0.36879169940948486
# Epoch 3, Training Loss 0.3534660800928023
# Saving a new best model
# Epoch 3, Validation Loss 0.35254088044166565
# Epoch 4, Training Loss 0.35155315479127375
# Saving a new best model
# Epoch 4, Validation Loss 0.34618592262268066
# Epoch 5, Training Loss 0.3464176855920776
# Saving a new best model
# Epoch 5, Validation Loss 0.341461181640625
# Epoch 6, Training Loss 0.34638618829289103
# Saving a new best model
# Epoch 6, Validation Loss 0.3381407558917999
# Epoch 7, Training Loss 0.3420000158674349
# Epoch 7, Validation Loss 0.34092265367507935
# Epoch 8, Training Loss 0.34050664808449704
# Epoch 8, Validation Loss 0.34026017785072327
# Epoch 9, Training Loss 0.3400569961565297
# Saving a new best model
# Epoch 9, Validation Loss 0.3361905515193939
# Epoch 10, Training Loss 0.33570379969792635
# Saving a new best model
# Epoch 10, Validation Loss 0.3357030153274536
# Epoch 11, Training Loss 0.3363966622003695
# Saving a new best model
# Epoch 11, Validation Loss 0.33502572774887085
# Epoch 12, Training Loss 0.33439182508282544
# Epoch 12, Validation Loss 0.33815130591392517
# Epoch 13, Training Loss 0.334190348360112
# Epoch 13, Validation Loss 0.3425155282020569
# Epoch 14, Training Loss 0.33628802576927636
# Epoch 14, Validation Loss 0.3414440155029297
# Epoch 15, Training Loss 0.33816983138884954
# Epoch 15, Validation Loss 0.3369184732437134
# Epoch 16, Training Loss 0.33464593791622455
# Epoch 16, Validation Loss 0.33561113476753235
# Epoch 17, Training Loss 0.3307343901899772
# Saving a new best model
# Epoch 17, Validation Loss 0.3349410593509674
# Epoch 18, Training Loss 0.33087095472870803
# Saving a new best model
# Epoch 18, Validation Loss 0.3348534107208252
# Epoch 19, Training Loss 0.33180144423149466
# Saving a new best model
# Epoch 19, Validation Loss 0.3341214656829834
# Epoch 20, Training Loss 0.32877880686182315
# Saving a new best model
# Epoch 20, Validation Loss 0.3339459300041199
# Epoch 21, Training Loss 0.3291647645637272
# Epoch 21, Validation Loss 0.33443471789360046
# Epoch 22, Training Loss 0.33090138174896316
# Epoch 22, Validation Loss 0.33406636118888855
# Epoch 23, Training Loss 0.32958104661325127
# Saving a new best model
# Epoch 23, Validation Loss 0.33324187994003296
# Epoch 24, Training Loss 0.3295017055016223
# Epoch 24, Validation Loss 0.3354572653770447
# Epoch 25, Training Loss 0.3262756300287518
# Epoch 25, Validation Loss 0.3335229158401489
# Epoch 26, Training Loss 0.3282581064395788
# Epoch 26, Validation Loss 0.335689902305603
# Epoch 27, Training Loss 0.326314202774831
# Epoch 27, Validation Loss 0.3333606421947479
# Epoch 28, Training Loss 0.32676974471991627
# Epoch 28, Validation Loss 0.34079301357269287
# Epoch 29, Training Loss 0.3240923840946298
# Epoch 29, Validation Loss 0.33591628074645996
# initialized Linear(in_features=512, out_features=32, bias=True)
# initialized Linear(in_features=9, out_features=32, bias=True)
# initialized Linear(in_features=64, out_features=32, bias=True)
# initialized Linear(in_features=32, out_features=1, bias=True)
# Test Loss 0.35541266202926636

# %%
bs_df
# Out:
#      train_loss valid_loss test_loss
# 32     0.311704   0.331152  0.350687
# 64      0.31301   0.328517  0.349622
# 128    0.312969   0.329269  0.349444
# 256    0.316306   0.330912  0.346489
# 512    0.323414   0.331122  0.350494
# 1024   0.324092   0.335916  0.355413

# %%
bs_df.to_pickle('./bs_df.pkl')
